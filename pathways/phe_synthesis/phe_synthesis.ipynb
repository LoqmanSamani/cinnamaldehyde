# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
reaction = pd.DataFrame({
    "Reaction Id": ["R-1", "R-2", "R-3", "R-4", "R-5", "R-6", "R-7", "R-8", "R-9", "R-10", "R-11", "R-12", "R-13",
                    "R-14", "R-15", "R-16", "R-17", "R-18", "R-19", "R-20", "R-21"],

    "Reaction": ["Glucose + ATP -> Glucose 6-phosphate + ADP",
                 "Glucose 6-phosphate <-> Fructose 6-phosphate",
                 "Fructose 6-phosphate + ATP -> Fructose 1,6-bisphosphate + ADP",
                 "Fructose 6-phosphate <-> Glyseraldehhyde 3-phosphate + Dehydroxyacetone phosphate",
                 "Phosphoenolpiruvate + H2O <-> 2-Phosphoglycerate",
                 "2-Phosphoglycerate <-> 3-Phosphoglycerate",
                 "3-Phosphoglycerate + ATP <-> 1,3-Phosphoglycerate + ADP",
                 "1,3-Phosphoglycerate + NADH + H⁺ <-> Glyseraldehhyde 3-phosphate + Pi",
                 "Glyseraldehhyde 3-phosphate  <-> Dehydroxyacetone phosphate",
                 "Xylulose 5-phosphate -> Glyceraldehyde 3-phosphate",
                 "Glyceraldehyde 3-phosphate -> Erythrose 4-phosphate",
                 "Erythrose 4-phosphate + Phosphoenolpiruvate + H2O -> 2-keto-3-deohy-D-arabinoheptulosonate 7-phosphate + Pi",
                 "2-keto-3-deohy-D-arabinoheptulosonate 7-phosphate NADH + H⁺ -> 3-Dehydroquinate + Pi + NAD⁺",
                 "3-Dehydroquinate -> 3-Dehxdroshikimate + H2O",
                 "3-Dehxdroshikimate + NAHPH + H⁺ -> Shikimate + NADP⁺",
                 "Shikimate + ATP -> Shikimate 3-phosphate + ADP",
                 "Shikimate 3-phosphate + Phosphoenolpiruvate -> 5-Enolpyruvylshikomate 3-phosphate + Pi",
                 "5-Enolpyruvylshikomate 3-phosphate -> Chorismate + Pi",
                 "Chorismate -> Prephenate",
                 "Prephenate -> Phenylpyruvate",
                 "Phenylpyruvate + CO2 + H2O -> L-Phenylalanine"
                 ],

    "Enzyme": ["Hexokinase", "Phosphohexose isomerase", "Phosphofructokinase-1", "Aldolase", "Enolase",
               "Phosphoglycerate mutase", "Phosphoglycerate kinase", "Glyceraldehyde 3-phosphate dehydrognase ",
               "Triose phosphate isomerase", "Transketolase", "Transaldolase",
               "2-keto-3-deohy-D-arabinoheptulosonate 7-phosphate synthase", "Dehydroquinate synthase",
               "3-dehydroquinate dehydratase", "Shikomate dehydrogenase", "Shikimate kinase",
               "5-Enolpyruvylshikomate 3-phosphate synthase", "Chorismate synthase", "chorismate mutase",
               "prephenate dehydratase", "Aromatic aminotransferase"],

    "Energy Consumption": ["1 ATP (ATP -> ADP)", None, "1 ATP (ATP -> ADP)", None, None, None, "1 ATP", "1 NADH",
                           None, None, None, None, "NADH", None, "NADPH", "ATP", None, None, None, None, None],

    "Pathway": ["Glycolysis (preparatory phase)", "Glycolysis (preparatory phase)",
                "Glycolysis (preparatory phase)", "Glycolysis (preparatory phase)",
                "Gluconeogenesis", "Gluconeogenesis", "Gluconeogenesis", "Gluconeogenesis", "Gluconeogenesis",
                "Pentose phosphate", "Pentose phosphate", "Shikimate", "Shikimate", "Shikimate", "Shikimate",
                "Shikimate", "Shikimate", "Shikimate", "Shikimate", "Shikimate", "Shikimate"],

    "Description": ["Phosphorylation of Glucose on carbon 6", "Isomerization moves the carbonyl-group to C-2",
                    "Phosphorylation of Fructose 6-phosphate on C-1",
                    "Cleavage of 6-carbon phosphate sugar to two 3-carbon phosphate carbon",
                    "Hydration", None, None, None, None, None, None, None, None, None, None,
                    None, None, None, None, None, None]
})

reaction
# Out:
#    Reaction Id                                           Reaction  \
# 0          R-1         Glucose + ATP -> Glucose 6-phosphate + ADP
# 1          R-2       Glucose 6-phosphate <-> Fructose 6-phosphate
# 2          R-3  Fructose 6-phosphate + ATP -> Fructose 1,6-bis...
# 3          R-4  Fructose 6-phosphate <-> Glyseraldehhyde 3-pho...
# 4          R-5   Phosphoenolpiruvate + H2O <-> 2-Phosphoglycerate
# 5          R-6          2-Phosphoglycerate <-> 3-Phosphoglycerate
# 6          R-7  3-Phosphoglycerate + ATP <-> 1,3-Phosphoglycer...
# 7          R-8  1,3-Phosphoglycerate + NADH + H⁺ <-> Glyserald...
# 8          R-9  Glyseraldehhyde 3-phosphate  <-> Dehydroxyacet...
# 9         R-10  Xylulose 5-phosphate -> Glyceraldehyde 3-phosp...
# 10        R-11  Glyceraldehyde 3-phosphate -> Erythrose 4-phos...
# 11        R-12  Erythrose 4-phosphate + Phosphoenolpiruvate + ...
# 12        R-13  2-keto-3-deohy-D-arabinoheptulosonate 7-phosph...
# 13        R-14       3-Dehydroquinate -> 3-Dehxdroshikimate + H2O
# 14        R-15  3-Dehxdroshikimate + NAHPH + H⁺ -> Shikimate +...
# 15        R-16     Shikimate + ATP -> Shikimate 3-phosphate + ADP
# 16        R-17  Shikimate 3-phosphate + Phosphoenolpiruvate ->...
# 17        R-18  5-Enolpyruvylshikomate 3-phosphate -> Chorisma...
# 18        R-19                           Chorismate -> Prephenate
# 19        R-20                       Prephenate -> Phenylpyruvate
# 20        R-21      Phenylpyruvate + CO2 + H2O -> L-Phenylalanine
#
#                                                Enzyme  Energy Consumption  \
# 0                                          Hexokinase  1 ATP (ATP -> ADP)
# 1                             Phosphohexose isomerase                None
# 2                               Phosphofructokinase-1  1 ATP (ATP -> ADP)
# 3                                            Aldolase                None
# 4                                             Enolase                None
# 5                             Phosphoglycerate mutase                None
# 6                             Phosphoglycerate kinase               1 ATP
# 7            Glyceraldehyde 3-phosphate dehydrognase               1 NADH
# 8                          Triose phosphate isomerase                None
# 9                                       Transketolase                None
# 10                                      Transaldolase                None
# 11  2-keto-3-deohy-D-arabinoheptulosonate 7-phosph...                None
# 12                            Dehydroquinate synthase                NADH
# 13                       3-dehydroquinate dehydratase                None
# 14                            Shikomate dehydrogenase               NADPH
# 15                                   Shikimate kinase                 ATP
# 16        5-Enolpyruvylshikomate 3-phosphate synthase                None
# 17                                Chorismate synthase                None
# 18                                  chorismate mutase                None
# 19                             prephenate dehydratase                None
# 20                          Aromatic aminotransferase                None
#
#                            Pathway  \
# 0   Glycolysis (preparatory phase)
# 1   Glycolysis (preparatory phase)
# 2   Glycolysis (preparatory phase)
# 3   Glycolysis (preparatory phase)
# 4                  Gluconeogenesis
# 5                  Gluconeogenesis
# 6                  Gluconeogenesis
# 7                  Gluconeogenesis
# 8                  Gluconeogenesis
# 9                Pentose phosphate
# 10               Pentose phosphate
# 11                       Shikimate
# 12                       Shikimate
# 13                       Shikimate
# 14                       Shikimate
# 15                       Shikimate
# 16                       Shikimate
# 17                       Shikimate
# 18                       Shikimate
# 19                       Shikimate
# 20                       Shikimate
#
#                                           Description
# 0              Phosphorylation of Glucose on carbon 6
# 1       Isomerization moves the carbonyl-group to C-2
# 2      Phosphorylation of Fructose 6-phosphate on C-1
# 3   Cleavage of 6-carbon phosphate sugar to two 3-...
# 4                                           Hydration
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
